# %%
dbutils.widgets.dropdown("time_period",'weekly',['weekly','monthly'])

# %%
from datetime import date,datetime,timedelta
from pyspark.sql.functions import *

time_period=dbutils.widgets.get("time_period")  
print(time_period)
today=date.today()

if time_period=='weekly':
    start_date=today-timedelta(days=today.weekday(),weeks=1)-timedelta(days=1)
    end_date=start_date+timedelta(days=6)

else:
    first=today.replace(day=1)
    end_date=first-timedelta(days=1)
    start_date=first-timedelta(days=end_date.day)

print(start_date,end_date)

# %%
df=spark.read.csv("/Volumes/retail_data/default/retails_store_data/superstore_data - superstore.csv",header=True,inferSchema=True)
display(df)

# %%
df.createOrReplaceTempView("sampleretail") #we are converting this file to view so we can perform sql on that. we are converting to virtual table

# %%
# %sql
select count(distinct Customer_id)from sampleretail

# %%
# %sql
select count(distinct Customer_id)from sampleretail where order_date between '2024-06-01' and '2024-06-30'

# %%
display(spark.sql(f"""select count(distinct Customer_id) from sampleretail where Order_Date between '{start_date}' and '{end_date}'"""))
#since we don't have data for year 2026 we are not getting any result

# %%
# %sql
select count(DISTINCT order_id) from sampleretail

# %%
display(spark.sql(f"""select count(distinct order_id) from sampleretail where Order_Date between '{start_date}' and '{end_date}'"""))
#since we don't have data for year 2026 we are not getting any result

# %%
# %sql
select sum(sales),sum(profit) from sampleretail

# %%
# %sql
select sum(sales),country from sampleretail  
group by country

# %%
# %sql
select sum(sales),country,region from sampleretail
group by 2,3
order by 1 desc
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
select sum(sales),category from sampleretail
group by 2
order by 1 desc
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
select sum(sales),sub_category from sampleretail
group by 2
order by 1 desc limit 10
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
select sum(quantity) ,product_name from sampleretail
group by 2
order by 1 desc limit 10
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
select sum(sales) ,customer_name,city from sampleretail
group by 2,3
order by 1 desc
