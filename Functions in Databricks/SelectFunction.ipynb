# %%
df=spark.read.csv("/Volumes/samplepractical/schema1/volume1/s1/employees.csv",header=True,inferSchema=True)

# %%
df.show()

# %%
df.printSchema()

# %%
df.select("First Name","Gender").show()

# %%
df.select(df.Team,df.Gender).show()

# %%
df.select(df.columns[1:4]).show()
