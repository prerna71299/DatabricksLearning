# %%
Empdf=spark.read.csv("/Volumes/samplepractical/schema1/volume1/s1/tableConvert.com_3mh587.csv",header=True,inferSchema=True)
df.show()

# %%
Deptdf=spark.read.csv("/Volumes/samplepractical/schema1/volume1/s1/tableConvert.com_6btxae.csv",header=True,inferSchema=True)
Deptdf.show()

# %%
Empdf.join(Deptdf,Empdf.Emp_ID==Deptdf.User,"inner").show()

# %%
Empdf.join(Deptdf,Empdf.Emp_ID==Deptdf.User,"left").show()

# %%
Empdf.join(Deptdf,Empdf.Emp_ID==Deptdf.User,"Right").show()

# %%
Empdf.join(Deptdf,Empdf.Emp_ID==Deptdf.User,"full_outer").show()

# %%
Empdf.join(Deptdf,Empdf.Emp_ID==Deptdf.User,"left_semi").show()

# %%
Empdf.join(Deptdf,Empdf.Emp_ID==Deptdf.User,"left_anti").show()
