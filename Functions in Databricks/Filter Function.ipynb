# %%
df=spark.read.csv("/Volumes/samplepractical/schema1/volume1/s1/employees.csv",header=True,inferSchema=True)

# %%
df.show()

# %%
df.filter(df.Gender=="Female").show()

# %%
df.filter(df.Gender!="Female").show()

# %%
df.filter((df.Gender=="Male")&(df.Team=="Finance")).show()

# %%
df.filter((df.Gender=="Female")|(df.Team=="Finance")).show()

# %%
df.filter(df.Team.startswith("B")).show()

# %%
df.filter(df.Team.endswith("e")).show()

# %%
df.filter(df.Team.contains("B")).show()

# %%
df.filter(df.Team.like("B%")).show()
