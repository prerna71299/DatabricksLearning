# %%
df=spark.read.csv("/Volumes/samplepractical/schema1/volume1/s1/tableConvert.com_3mh587.csv",header=True,inferSchema=True)

# %%
df.printSchema()

# %%
df.show()

# %%
df.na.fill("").show()

# %%
df.na.fill(0).show()

# %%
df.na.fill("unknown").show()

# %%
df.fillna("").show()

# %%
df.na.fill("",["Emp_ID"]).show()

# %%
df.na.fill("",["Emp_ID"]).na.fill("other",["Loc"]).show()
