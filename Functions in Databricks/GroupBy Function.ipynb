# %%
df=spark.read.csv("/Volumes/samplepractical/schema1/volume1/s1/employees.csv",header=True,inferSchema=True)

# %%
df.show()

# %%
df.groupBy("Team").sum("Salary").show()

# %%
df.groupBy("Gender").min("Salary").show()

# %%
df.groupBy("Team").mean("Salary").show()

# %%
df.groupBy("Team").count().show()

# %%
df.groupBy("Team","Gender").max("Salary").show()
