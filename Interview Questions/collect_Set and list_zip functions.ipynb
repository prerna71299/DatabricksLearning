# %%
#Group multiple rows into a single row

data=[(1,'Manish','Mobile'),(1,'Manish','Washing Mavhine'),(2,'Rahul','Car'),(2,'Rahul','mobile'),(2,'Rahul','scooty'),(3,'Monu','Scooty')]
schema=["Customer_ID", "Customer_Name",'Purchase']
df = spark.createDataFrame(data,schema)
df.show()

# %%
df.createOrReplaceTempView("Sample")

# %%
# %sql
select Customer_ID,Customer_Name,collect_set(Purchase) from Sample group by 1,2

# %%
from pyspark.sql.functions import *
df.groupBy("Customer_ID","Customer_Name").agg(collect_set("Purchase")).show()

# %%
#How to combine many list

list1 = ["a", "b", "c", "d"]
list2 = [1, 2, 3, 4]

# Minimal fix: use spark.createDataFrame directly

df = spark.createDataFrame(list(zip(list1, list2)), ["column1", "column2"])
df.show()
