# %%
df=spark.read.csv('dbfs:/Volumes/samplepractical/schema1/volume1/s1/employees.csv')

# %%
df.show()

# %%
display(df)

# %%
df=spark.read.csv('dbfs:/Volumes/samplepractical/schema1/volume1/s1/employees.csv',header=True)

# %%
display(df)

# %%
df.printSchema()

# %%
df=spark.read.csv('dbfs:/Volumes/samplepractical/schema1/volume1/s1/employees.csv',header=True,inferSchema=True)

# %%
df.printSchema()

# %%
df2=spark.read.format("CSV").option("header","true").option("inferSchema","true").load("dbfs:/Volumes/samplepractical/schema1/volume1/s1/employees.csv")

# %%
display(df2)
